# %% [markdown]
# # Simulaciones LTSpice

# %% [markdown]
# ## Ejercicio 1
#
# ![Ejer1_Simu.JPG](attachment:Ejer1_Simu.JPG)

# %% [markdown]
# ## Ejercicio 2
#
# ![image.png](attachment:image.png)
#
# #### Banda de Paso:
#
# ![image-2.png](attachment:image-2.png)
#
# Se confirma atenuacion maxima de 0.5dB con ganancia de 20dB
#
# #### Banda de Atenuacion:
#
# ![image-3.png](attachment:image-3.png)
#
# Se verifica una atenuacion minima de 20dB en la banda de stop

# %% [markdown]
# ## Ejercicio 3
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Verificamos que se cumplan las atenuaciones pedidas en la frecuencia de paso y en la frecuencia de stop:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Analizando más de cerca la respuesta en módulo, podemos ver los picos producidos debido a que es un filtro Chebyshev de orden 5. Vemos que l oscilación se produce entre 0dB y -0.4dB (alfa min)

# %% [markdown]
# ## Ejercicio 4
#
# Circuito de secciones pasivas:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Circuito con inductores activadas:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Se superponen completamente en fase y módulo

# %% [markdown]
# ## Ejercicio 5
#
# ![Ejer5_Simu.JPG](attachment:Ejer5_Simu.JPG)

# %% [markdown]
# ![Ejer5_Activado_Simu%20%282%29.JPG](attachment:Ejer5_Activado_Simu%20%282%29.JPG)

# %% [markdown]
# ## Ejercicio 6
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Verificamos cumplir con la atenuación máxima (1dB) en la frecuencia de paso (1591 Hz):
#
# ![image-3.png](attachment:image-3.png)
#
# Vemos el retardo de grupo y verificamos que se mantenga constante en 100us (margen de 10% de error) hasta f = 3978.87 Hz):
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# Vemos que el retardo de grupo se mantiene constante en 100uS hasta los 2,7KHz momento en el cual empieza a disminuir. Podemos observar que en 3,98Khz el retardo es de 95us, por lo que estamos dentro del rango permitido por las condiciones de diseño.

# %% [markdown]
# ## Ejercicio 7
#
# ![image.png](attachment:image.png)
#
# #### Banda de Paso:
#
# ![image-2.png](attachment:image-2.png)
#
# Se confirma el BW = 900kHz y la atenuacion maxima de 3dB con ganancia de 10dB
#
# #### Banda de Atenuacion
#
# ![image-3.png](attachment:image-3.png)
#
# Se verifica una atenuacion minima de 20dB en la banda de stop

# %% [markdown]
# ## Ejercicio 8
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
